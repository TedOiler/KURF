# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy.stats import f_oneway
from scipy.stats import tukey_hsd

# %%
def improvement_curve(data_dict, start_index):
    #convert the dictionary to a list of items, sorted by the keys 
    data_list = sorted(list(data_dict.items()))
    result_curve = []
    result_curve.append(data_list[start_index][1])
    for i in range(start_index,len(data_list)-1):
        if data_list[i][1] > result_curve[-1]:
            result_curve.append(data_list[i][1])
        else: result_curve.append(result_curve[-1])
    return result_curve

# %%
def show_improvement_curve_diagram(mappings_lst, start_idx):   
    improve_iter_num_lst = []
    for local_opt_mappings in mappings_lst:
        improve_iter_num_lst.append(improvement_curve(local_opt_mappings, start_index = start_idx))

    x_value=range(len(improve_iter_num_lst[0]))
    for i, y_values in enumerate(improve_iter_num_lst):
        if len(y_values) < len(x_value):
            temp = len(improve_iter_num_lst[0])
            while len(y_values) < len(x_value):
                temp = temp - 1
                x_value=range(temp)
        if len(y_values) > len(x_value):
            while len(y_values) > len(x_value):
                y_values.pop()
        plt.plot(x_value, y_values, linestyle='--', label=f'Data {i+1}',color = 'skyblue')

    plt.title('improvement curve')
    plt.xlabel('number of iterations')
    plt.ylabel('improved result')
    plt.show()

# %%
# %store -r
len(ackley_results)
len(schaffer_results)
# Out:
# 36

# %%
show_improvement_curve_diagram(ackley_results['ack_ei_8_ff'], 9)

# %%
show_improvement_curve_diagram(ackley_results['ack_ei_12_ff'], 13)

# %%
show_improvement_curve_diagram(ackley_results['ack_ei_14_ff'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_pi_8_ff'], 9)

# %%
show_improvement_curve_diagram(ackley_results['ack_pi_12_ff'], 13)

# %%
show_improvement_curve_diagram(ackley_results['ack_pi_14_ff'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ucb_8_ff'], 9)

# %%
show_improvement_curve_diagram(ackley_results['ack_ucb_12_ff'], 13)

# %%
show_improvement_curve_diagram(ackley_results['ack_ucb_14_ff'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ei_8_ff'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ei_12_ff'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ei_14_ff'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_pi_8_ff'], 9)
show_improvement_curve_diagram(schaffer_results['sch_pi_12_ff'], 13)
show_improvement_curve_diagram(schaffer_results['sch_pi_14_ff'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ucb_8_ff'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ucb_12_ff'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ucb_14_ff'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ei_8_rd'], 9)
show_improvement_curve_diagram(ackley_results['ack_ei_12_rd'], 13)
show_improvement_curve_diagram(ackley_results['ack_ei_14_rd'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_pi_8_rd'], 9)
show_improvement_curve_diagram(ackley_results['ack_pi_12_rd'], 13)
show_improvement_curve_diagram(ackley_results['ack_pi_14_rd'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ucb_8_rd'], 9)
show_improvement_curve_diagram(ackley_results['ack_ucb_12_rd'], 13)
show_improvement_curve_diagram(ackley_results['ack_ucb_14_rd'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ei_8_rd'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ei_12_rd'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ei_14_rd'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_pi_8_rd'], 9)
show_improvement_curve_diagram(schaffer_results['sch_pi_12_rd'], 13)
show_improvement_curve_diagram(schaffer_results['sch_pi_14_rd'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ucb_8_rd'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ucb_12_rd'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ucb_14_rd'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ei_8_do'], 9)
show_improvement_curve_diagram(ackley_results['ack_ei_12_do'], 13)
show_improvement_curve_diagram(ackley_results['ack_ei_14_do'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_pi_8_do'], 9)
show_improvement_curve_diagram(ackley_results['ack_pi_12_do'], 13)
show_improvement_curve_diagram(ackley_results['ack_pi_14_do'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ucb_8_do'], 9)
show_improvement_curve_diagram(ackley_results['ack_ucb_12_do'], 13)
show_improvement_curve_diagram(ackley_results['ack_ucb_14_do'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ei_8_do'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ei_12_do'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ei_14_do'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_pi_8_do'], 9)
show_improvement_curve_diagram(schaffer_results['sch_pi_12_do'], 13)
show_improvement_curve_diagram(schaffer_results['sch_pi_14_do'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ucb_8_do'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ucb_12_do'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ucb_14_do'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ei_8_io'], 9)
show_improvement_curve_diagram(ackley_results['ack_ei_12_io'], 13)
show_improvement_curve_diagram(ackley_results['ack_ei_14_io'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_pi_8_io'], 9)
show_improvement_curve_diagram(ackley_results['ack_pi_12_io'], 13)
show_improvement_curve_diagram(ackley_results['ack_pi_14_io'], 15)

# %%
show_improvement_curve_diagram(ackley_results['ack_ucb_8_io'], 9)
show_improvement_curve_diagram(ackley_results['ack_ucb_12_io'], 13)
show_improvement_curve_diagram(ackley_results['ack_ucb_14_io'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ei_8_io'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ei_12_io'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ei_14_io'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_pi_8_io'], 9)
show_improvement_curve_diagram(schaffer_results['sch_pi_12_io'], 13)
show_improvement_curve_diagram(schaffer_results['sch_pi_14_io'], 15)

# %%
show_improvement_curve_diagram(schaffer_results['sch_ucb_8_io'], 9)
show_improvement_curve_diagram(schaffer_results['sch_ucb_12_io'], 13)
show_improvement_curve_diagram(schaffer_results['sch_ucb_14_io'], 15)
